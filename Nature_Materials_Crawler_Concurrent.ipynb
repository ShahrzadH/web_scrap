# %%
import requests
import time
from bs4 import BeautifulSoup
import concurrent.futures
import pandas as pd
import functools

# %%
def create_url(page):
    return "https://www.nature.com/nmat/articles?searchType=journalSearch&sort=PubDate&type=article&page=" + str(page)

# %%
def retrieve_page(url):
    titles = []
    links = []
    abstracts  = []
    biblios = []
    authors = []
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text, "lxml")
    for link in soup.findAll('a' ,  {'data-track-action' : 'view article'}):
            href = 'https://www.nature.com' + link.get('href')
            title = link.text.replace('\n', '').lstrip()
            links.append(href)
            titles.append(title)
            source_code_link = requests.get(href) 
            plain_text_link = source_code_link.text
            soup_link = BeautifulSoup(plain_text_link, "lxml")            
            abstracts.append(get_single_article_abstract(soup_link, href))
            biblios.append(get_single_article_datepublished(soup_link, href))
            authors.append(get_single_article_firstauthor(soup_link, href))
    return links, titles, abstracts, biblios, authors

# %%
def get_single_article_abstract(soup, article_url):
#     source_code = requests.get(article_url) 
#     plain_text = source_code.text
#     soup = BeautifulSoup(plain_text, "lxml")
    abstract = ""
    for article_abstract in soup.findAll('div', {'id':['Abs1-content', 'abstract-content']}):
        abstract = article_abstract.text
        #print(abstract)
    return abstract

# %%
def get_single_article_datepublished(soup, article_url):
#     source_code = requests.get(article_url) 
#     plain_text = source_code.text
#     soup = BeautifulSoup(plain_text, "lxml")
    biblio = ""
    for article_biblio in soup.findAll('a', {'href':"#article-info"}):
        biblio = article_biblio.text
        #print(biblio)
    return biblio

# %%
def get_single_article_firstauthor(soup, article_url):
    author = ""
    for article_author in soup.findAll('a', {'href':"#auth-1"}):
        author = article_author.text
        #print(author)
    return author

# %%
urls = [create_url(page) for page in range(1,26)]

# %%
def concat(x,y):
    return list(x[i]+y[i] for i in range(len(x)))

# %%
# %%time
with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:
    result = list(executor.map(retrieve_page, urls))
# Out:
# CPU times: user 5min 14s, sys: 13.9 s, total: 5min 28s
# Wall time: 7min 56s

# %%
result_concat = functools.reduce(concat, result)
d = list(map(list, zip(*result_concat)))
result_df =pd.DataFrame(d)
result_df.head()
# Out:
#                                                    0  \
# 0  https://www.nature.com/articles/s41563-019-0423-3
# 1  https://www.nature.com/articles/s41563-019-0421-5
# 2  https://www.nature.com/articles/s41563-019-0422-4
# 3  https://www.nature.com/articles/s41563-019-0427-z
# 4  https://www.nature.com/articles/s41563-019-0415-3
#
#                                                    1  \
# 0  Quantum jamming transition to a correlated ele...
# 1  Spatially dispersive circular photogalvanic ef...
# 2  Predictive model of hydrogen trapping and bubb...
# 3  Intermediate-sized molecular sieving of styren...
# 4  Formation of two-dimensional transition metal ...
#
#                                                    2                        3  \
# 0  Distinct many-body states may be created under...  Published: 15 July 2019
# 1  Weyl semimetals (WSMs) are gapless topological...  Published: 15 July 2019
# 2  The interplay between hydrogen and nanovoids, ...  Published: 15 July 2019
# 3  Molecular sieving can lead to ultrahigh select...  Published: 15 July 2019
# 4  Two-dimensional (2D) materials have attracted ...  Published: 08 July 2019
#
#                          4
# 0  Yaroslav A. Gerasimenko
# 1                Zhurun Ji
# 2                  Jie Hou
# 3           Dong-Dong Zhou
# 4                Juan Yang

# %%
result_df
# Out:
#                                                     0  \
# 0   https://www.nature.com/articles/s41563-019-0423-3
# 1   https://www.nature.com/articles/s41563-019-0421-5
# 2   https://www.nature.com/articles/s41563-019-0422-4
# 3   https://www.nature.com/articles/s41563-019-0427-z
# 4   https://www.nature.com/articles/s41563-019-0415-3
# 5   https://www.nature.com/articles/s41563-019-0418-0
# 6   https://www.nature.com/articles/s41563-019-0412-6
# 7   https://www.nature.com/articles/s41563-019-0398-0
# 8   https://www.nature.com/articles/s41563-019-0416-2
# 9   https://www.nature.com/articles/s41563-019-0407-3
# 10  https://www.nature.com/articles/s41563-019-0377-5
# 11  https://www.nature.com/articles/s41563-019-0389-1
# 12  https://www.nature.com/articles/s41563-019-0396-2
# 13  https://www.nature.com/articles/s41563-019-0382-8
# 14  https://www.nature.com/articles/s41563-019-0387-3
# 15  https://www.nature.com/articles/s41563-019-0388-2
# 16  https://www.nature.com/articles/s41563-019-0379-3
# 17  https://www.nature.com/articles/s41563-019-0370-z
# 18  https://www.nature.com/articles/s41563-019-0381-9
# 19  https://www.nature.com/articles/s41563-019-0378-4
# 20  https://www.nature.com/articles/s41563-019-0385-5
# 21  https://www.nature.com/articles/s41563-019-0371-y
# 22  https://www.nature.com/articles/s41563-019-0368-6
# 23  https://www.nature.com/articles/s41563-019-0369-5
# 24  https://www.nature.com/articles/s41563-019-0367-7
# 25  https://www.nature.com/articles/s41563-019-0374-8
# 26  https://www.nature.com/articles/s41563-019-0361-0
# 27  https://www.nature.com/articles/s41563-019-0354-z
# 28  https://www.nature.com/articles/s41563-019-0364-x
# 29  https://www.nature.com/articles/s41563-019-0348-x
# 30  https://www.nature.com/articles/s41563-019-0336-1
# 31  https://www.nature.com/articles/s41563-019-0349-9
# 32  https://www.nature.com/articles/s41563-019-0344-1
# 33  https://www.nature.com/articles/s41563-019-0347-y
# 34  https://www.nature.com/articles/s41563-019-0343-2
# 35  https://www.nature.com/articles/s41563-019-0342-3
# 36  https://www.nature.com/articles/s41563-019-0340-5
# 37  https://www.nature.com/articles/s41563-019-0325-4
# 38  https://www.nature.com/articles/s41563-019-0315-6
# 39  https://www.nature.com/articles/s41563-019-0323-6
# 40  https://www.nature.com/articles/s41563-019-0311-x
# 41  https://www.nature.com/articles/s41563-019-0318-3
# 42  https://www.nature.com/articles/s41563-019-0309-4
# 43  https://www.nature.com/articles/s41563-019-0320-9
# 44  https://www.nature.com/articles/s41563-019-0307-6
# 45  https://www.nature.com/articles/s41563-019-0317-4
# 46  https://www.nature.com/articles/s41563-019-0305-8
# 47  https://www.nature.com/articles/s41563-019-0321-8
# 48  https://www.nature.com/articles/s41563-019-0296-5
# 49  https://www.nature.com/articles/s41563-019-0297-4
#
#                                                     1  \
# 0   Quantum jamming transition to a correlated ele...
# 1   Spatially dispersive circular photogalvanic ef...
# 2   Predictive model of hydrogen trapping and bubb...
# 3   Intermediate-sized molecular sieving of styren...
# 4   Formation of two-dimensional transition metal ...
# 5   Scalable in operando strain tuning in nanophot...
# 6   Regioselective generation and reactivity contr...
# 7   Resorcinol–formaldehyde resins as metal-free s...
# 8   High-resolution remote thermometry and thermog...
# 9   Shape-encoded dynamic assembly of mobile micro...
# 10  Long-term implant fibrosis prevention in roden...
# 11  Single crystal texture by directed molecular s...
# 12      A map of the inorganic ternary metal nitrides
# 13  Quantitative imaging of electric surface poten...
# 14  Diffraction imaging of nanocrystalline structu...
# 15  Mixed proton and electron conducting double pe...
# 16  Formation of aligned periodic patterns during ...
# 17  Long-range chiral exchange interaction in synt...
# 18  Traction forces at the cytokinetic ring regula...
# 19  Molecular optical imaging probes for early dia...
# 20  Targeted homology-directed repair in blood ste...
# 21  A mechano-signalling network linking microtubu...
# 22  Parenchymal and stromal tissue regeneration of...
# 23    Anisotropic spin fluctuations in detwinned FeSe
# 24  Bioactive site-specifically modified proteins ...
# 25  Shear-strain-mediated magnetoelectric effects ...
# 26  Highly stable fullerene-based porous molecular...
# 27  Gap suppression at a Lifshitz transition in a ...
# 28  The ground exciton state of formamidinium lead...
# 29  Deterministic optical control of room temperat...
# 30  Ultrafast generation and control of an electro...
# 31  Structural evolution of atomically dispersed P...
# 32  Reversible and cooperative photoactivation of ...
# 33  General rule for the energy of water-induced t...
# 34  Rigid helical-like assemblies from a self-aggr...
# 35  Site-selective CO disproportionation mediated ...
# 36  Multi-scale ordering in highly stretchable pol...
# 37  Metal–polymer hybrid nanomaterials for plasmon...
# 38  Cellulose ionic conductors with high different...
# 39  An integrin αIIbβ3 intermediate affinity state...
# 40  Optical creation of a supercrystal with three-...
# 41  Unified picture of anionic redox in Li/Na-ion ...
# 42  The Fermi surface geometrical origin of axis-d...
# 43  Ultrahigh conductivity in Weyl semimetal NbAs ...
# 44  Local nascent protein deposition and remodelli...
# 45  Pressure promoted low-temperature melting of m...
# 46  Polymer–inorganic solid–electrolyte interphase...
# 47  Growth of environmentally stable transition me...
# 48  Nonlinear photoresponse of type-II Weyl semime...
# 49  Colossal mid-infrared bulk photovoltaic effect...
#
#                                                     2  \
# 0   Distinct many-body states may be created under...
# 1   Weyl semimetals (WSMs) are gapless topological...
# 2   The interplay between hydrogen and nanovoids, ...
# 3   Molecular sieving can lead to ultrahigh select...
# 4   Two-dimensional (2D) materials have attracted ...
# 5   The quest for an integrated quantum optics pla...
# 6   Subnanometric metal species (single atoms and ...
# 7   Artificial photosynthesis is a critical challe...
# 8   Although metal-halide perovskites have recentl...
# 9   Field-directed and self-propelled colloidal as...
# 10  Implantable medical devices have revolutionize...
# 11  Creating well-defined single-crystal textures ...
# 12  Exploratory synthesis in new chemical spaces i...
# 13  Because materials consist of positive nuclei a...
# 14  The properties of organic solids depend on the...
# 15  Hydrogen production from water electrolysis is...
# 16  Self-organizing patterns with micrometre-scale...
# 17  The exchange interaction governs static and dy...
# 18  Epithelial repair and regeneration are driven ...
# 19  Drug-induced acute kidney injury (AKI) with a ...
# 20  Ex vivo CRISPR gene editing in haematopoietic ...
# 21  The interrelationship between microtubules and...
# 22  Cells are transplanted to regenerate an organs...
# 23  Superconductivity in FeSe emerges from a nemat...
# 24  Protein-modified biomaterials can be used to m...
# 25  Large changes in the magnetization of ferromag...
# 26  The synthesis of conventional porous crystals ...
# 27  In multi-orbital materials, superconductivity ...
# 28  Lead halide perovskites have emerged as promis...
# 29  Controlling ferroic orders (ferroelectricity, ...
# 30  Vortex-carrying matter waves, such as chiral e...
# 31  The use of oxide-supported isolated Pt-group m...
# 32  The reversible and cooperative activation proc...
# 33  Charge carrier traps are generally highly detr...
# 34  The structural versatility, biocompatibility a...
# 35  Recent reports of hot-electron-induced dissoci...
# 36  Stretchable semiconducting polymers have been ...
# 37  Hydrogen–air mixtures are highly flammable. Hy...
# 38  Converting low-grade heat into useful electric...
# 39  Integrins are membrane receptors that mediate ...
# 40  Stimulation with ultrafast light pulses can re...
# 41  Anionic redox in Li-rich and Na-rich transitio...
# 42  Electronic materials generally exhibit a singl...
# 43  In two-dimensional (2D) systems, high mobility...
# 44  Hydrogels serve as valuable tools for studying...
# 45  Metal–organic frameworks (MOFs) are microporou...
# 46  The solid–electrolyte interphase (SEI) is pivo...
# 47  Two-dimensional transition metal selenides (TM...
# 48  The experimental manifestation of topological ...
# 49  Broadband, efficient and fast conversion of li...
#
#                            3                        4
# 0    Published: 15 July 2019  Yaroslav A. Gerasimenko
# 1    Published: 15 July 2019                Zhurun Ji
# 2    Published: 15 July 2019                  Jie Hou
# 3    Published: 15 July 2019           Dong-Dong Zhou
# 4    Published: 08 July 2019                Juan Yang
# 5    Published: 08 July 2019             Joel Q. Grim
# 6    Published: 01 July 2019               Lichen Liu
# 7    Published: 01 July 2019       Yasuhiro Shiraishi
# 8    Published: 01 July 2019           Sergii Yakunin
# 9    Published: 24 June 2019             Yunus Alapan
# 10   Published: 24 June 2019              Shady Farah
# 11   Published: 17 June 2019               Xunda Feng
# 12   Published: 17 June 2019               Wenhao Sun
# 13   Published: 10 June 2019         Christian Wagner
# 14   Published: 03 June 2019           Ouliana Panova
# 15   Published: 03 June 2019          Einar Vøllestad
# 16   Published: 03 June 2019         John S. Bangsund
# 17   Published: 03 June 2019             Dong-Soo Han
# 18   Published: 03 June 2019              Marina Uroz
# 19    Published: 27 May 2019             Jiaguo Huang
# 20    Published: 27 May 2019            Reza Shahbazi
# 21    Published: 21 May 2019     Nisha Bte Mohd Rafiq
# 22    Published: 21 May 2019                  Ling He
# 23    Published: 20 May 2019                Tong Chen
# 24    Published: 20 May 2019         Jared A. Shadish
# 25    Published: 20 May 2019               M. Ghidini
# 26    Published: 13 May 2019          C. Grazia Bezzu
# 27    Published: 13 May 2019                 G. Singh
# 28    Published: 13 May 2019         Philippe Tamarat
# 29    Published: 06 May 2019               Yi-De Liou
# 30    Published: 06 May 2019           G. M. Vanacore
# 31  Published: 22 April 2019               Leo DeRita
# 32  Published: 22 April 2019          Byoung-Hoon Lee
# 33  Published: 22 April 2019           Guangzheng Zuo
# 34  Published: 15 April 2019               Santu Bera
# 35  Published: 15 April 2019        Wei-Chang D. Yang
# 36  Published: 15 April 2019                   Jie Xu
# 37  Published: 01 April 2019      Ferry A. A. Nugroho
# 38  Published: 25 March 2019                  Tian Li
# 39  Published: 25 March 2019             Yunfeng Chen
# 40  Published: 18 March 2019             V. A. Stoica
# 41  Published: 18 March 2019          Mouna Ben Yahia
# 42  Published: 18 March 2019                   Bin He
# 43  Published: 18 March 2019              Cheng Zhang
# 44  Published: 18 March 2019           Claudia Loebel
# 45  Published: 18 March 2019           Remo N. Widmer
# 46  Published: 11 March 2019                  Yue Gao
# 47  Published: 11 March 2019               Huihui Lin
# 48  Published: 04 March 2019               Junchao Ma
# 49  Published: 04 March 2019      Gavin B. Osterhoudt

# %%
result_df.columns=['links', 'titles','abstracts', 'date_published', 'author']

# %%
result_df.head()
# Out:
#                                                links  \
# 0  https://www.nature.com/articles/s41563-019-0423-3
# 1  https://www.nature.com/articles/s41563-019-0421-5
# 2  https://www.nature.com/articles/s41563-019-0422-4
# 3  https://www.nature.com/articles/s41563-019-0427-z
# 4  https://www.nature.com/articles/s41563-019-0415-3
#
#                                               titles  \
# 0  Quantum jamming transition to a correlated ele...
# 1  Spatially dispersive circular photogalvanic ef...
# 2  Predictive model of hydrogen trapping and bubb...
# 3  Intermediate-sized molecular sieving of styren...
# 4  Formation of two-dimensional transition metal ...
#
#                                            abstracts           date_published  \
# 0  Distinct many-body states may be created under...  Published: 15 July 2019
# 1  Weyl semimetals (WSMs) are gapless topological...  Published: 15 July 2019
# 2  The interplay between hydrogen and nanovoids, ...  Published: 15 July 2019
# 3  Molecular sieving can lead to ultrahigh select...  Published: 15 July 2019
# 4  Two-dimensional (2D) materials have attracted ...  Published: 08 July 2019
#
#                     author
# 0  Yaroslav A. Gerasimenko
# 1                Zhurun Ji
# 2                  Jie Hou
# 3           Dong-Dong Zhou
# 4                Juan Yang

# %%
result_df.to_csv("complete_result")
